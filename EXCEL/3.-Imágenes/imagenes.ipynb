# %% [markdown]
# # Райхан

# %%
#Он используется для использования изображений в программировании.
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
адрес_Райхан = "D:/DataScience/Yakomo/EXCEL/3.-Imágenes/photo_5343799267917152247_y.jpg"
изображение = Image.open(адрес_Райхан)

# %%
size = (665,500)
изображение = изображение.resize(size)

# %%
изображение
# Out:
# <PIL.Image.Image image mode=RGB size=665x500>
