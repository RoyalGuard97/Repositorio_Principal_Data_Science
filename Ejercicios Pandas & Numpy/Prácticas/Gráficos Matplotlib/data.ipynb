# %%
import pandas as pd

# %%
#Skiprows saltea filas que no aportan al dataframe
df = pd.read_csv("ventasTotales.csv",skiprows=5,sep=";",decimal = ",") #Sep es el separador

# %%
df
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 0     1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1     1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2     1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3     1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4     1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# ..         ...               ...    ...                ...          ...
# 455  31/1/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  31/1/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades  Ganancia
# 0           6     18.00
# 1           8      3.84
# 2           3      6.30
# ...

# %%
#Registros y Columnas de un Dataframe
df.shape #Confirmamos nuestras dimensiones
# Out:
# (460, 7)

# %%
#Muestra las primersa 5 filas
df.head()
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 0  1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2  1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
#
#    Unidades  Ganancia
# 0         6     18.00
# 1         8      3.84
# 2         3      6.30
# 3         9     14.40
# 4        14      6.72

# %%
#Muestra las últimas 5 filas
df.tail()
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 455  31/1/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  31/1/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades  Ganancia
# 455         6      16.5
# 456        11     115.5
# 457         4       6.4
# 458         8       6.8
# 459         7       2.1

# %%
#Mostrar 5 Registros Aleatorios
df.sample(5)
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 428  29/1/2016      Steve Ashton  Norte  Sánguche de Queso  Comestibles
# 254  17/1/2016   Desmond Delaney    Sur            Cerveza  Comestibles
# 434  30/1/2016  Trevor Snodgrass  Norte         Calcetines   Vestimenta
# 101   7/1/2016      Steve Ashton  Oeste             Escoba        Hogar
# 437  30/1/2016  Trevor Snodgrass   Este         Calcetines   Vestimenta
#
#      Unidades  Ganancia
# 428        15     24.00
# 254         4      1.60
# 434         7     15.75
# 101        13     47.45
# 437        10     22.50

# %%
#Información de los Datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha      460 non-null    object
#  1   Vendedor   460 non-null    object
#  2   Región     460 non-null    object
#  3   Artículo   460 non-null    object
#  4   Categoría  460 non-null    object
#  5   Unidades   460 non-null    int64
#  6   Ganancia   460 non-null    float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 25.3+ KB

# %%
#Cuenta cuantos elementos existen por categoría de dato. 
df["Región"].value_counts()
# Out:
# Este     138
# Sur      120
# Oeste    102
# Norte    100
# Name: Región, dtype: int64

# %%
#Por categoría Vendedor ¿Cuantos Registros existen?
df["Vendedor"].value_counts()
# Out:
# Sarah Bond          86
# Steve Ashton        84
# Desmond Delaney     76
# Trevor Snodgrass    75
# Dustin Gee          70
# Boris Stanford      69
# Name: Vendedor, dtype: int64

# %%
df
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 0     1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1     1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2     1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3     1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4     1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# ..         ...               ...    ...                ...          ...
# 455  31/1/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  31/1/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades  Ganancia
# 0           6     18.00
# 1           8      3.84
# 2           3      6.30
# ...

# %%
#Generamos la vista de un Dataframe que se encuentra ordenado en primera instancia
#Por el vendedor en orden alfabético y en segundo por su ganancia. 
df.sort_values(by=["Vendedor","Ganancia"])
# Out:
#          Fecha          Vendedor Región   Artículo    Categoría  Unidades  \
# 93    6/1/2016    Boris Stanford  Norte  Chocolate  Comestibles         2
# 450  31/1/2016    Boris Stanford   Este  Chocolate  Comestibles         3
# 259  18/1/2016    Boris Stanford    Sur  Pepinillo  Comestibles         5
# 25    2/1/2016    Boris Stanford   Este        Pan  Comestibles         4
# 64    5/1/2016    Boris Stanford    Sur        Pan  Comestibles         4
# ..         ...               ...    ...        ...          ...       ...
# 442  31/1/2016  Trevor Snodgrass   Este  Sandalias   Vestimenta         6
# 225  15/1/2016  Trevor Snodgrass   Este   Sudadera   Vestimenta        12
# 158  11/1/2016  Trevor Snodgrass  Oeste   Sudadera   Vestimenta        13
# 436  30/1/2016  Trevor Snodgrass  Oeste  Sandalias   Vestimenta        10
# 419  29/1/2016  Trevor Snodgrass  Norte  Sandalias   Vestimenta        11
#
#      Ganancia
# 93       0.96
# 450      1.44
# 259      1.50
# 25       1.60
# ...

# %%
df
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 0     1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1     1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2     1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3     1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4     1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# ..         ...               ...    ...                ...          ...
# 455  31/1/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  31/1/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades  Ganancia
# 0           6     18.00
# 1           8      3.84
# 2           3      6.30
# ...

# %%
df.columns = ["fecha","vendedor","region","articulo","categoria","unidades","ganancia"]

# %%
df
# Out:
#          fecha          vendedor region           articulo    categoria  \
# 0     1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1     1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2     1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3     1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4     1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# ..         ...               ...    ...                ...          ...
# 455  31/1/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  31/1/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      unidades  ganancia
# 0           6     18.00
# 1           8      3.84
# 2           3      6.30
# ...

# %%
condicion = (df["categoria"] == "Vestimenta")
df[condicion]
# Out:
#          fecha          vendedor region          articulo   categoria  \
# 0     1/1/2016      Steve Ashton  Norte  Medias Femeninas  Vestimenta
# 2     1/1/2016        Sarah Bond    Sur            Gorras  Vestimenta
# 7     1/1/2016      Steve Ashton  Oeste            Gorras  Vestimenta
# 11    1/1/2016    Boris Stanford  Oeste        Calcetines  Vestimenta
# 12    1/1/2016  Trevor Snodgrass    Sur            Shorts  Vestimenta
# ..         ...               ...    ...               ...         ...
# 443  31/1/2016        Sarah Bond    Sur        Calcetines  Vestimenta
# 446  31/1/2016  Trevor Snodgrass  Oeste          Sudadera  Vestimenta
# 449  31/1/2016    Boris Stanford   Este          Sudadera  Vestimenta
# 455  31/1/2016        Sarah Bond    Sur           Bufanda  Vestimenta
# 456  31/1/2016        Dustin Gee   Este         Sandalias  Vestimenta
#
#      unidades  ganancia
# 0           6     18.00
# 2           3      6.30
# 7           2      4.20
# 11          7     15.75
# ...

# %%
df.dtypes
# Out:
# fecha         object
# vendedor      object
# region        object
# articulo      object
# categoria     object
# unidades       int64
# ganancia     float64
# dtype: object

# %%
condicion = df["vendedor"].str.contains("Trevor")
df[condicion]["vendedor"].value_counts()
# Out:
# Trevor Snodgrass    75
# Name: vendedor, dtype: int64

# %%
#Quiero a los vendedores cuyo nombre empiecen con B papu
condicion = df["vendedor"].str.startswith("S")
df[condicion]["vendedor"].value_counts()
# Out:
# Sarah Bond      86
# Steve Ashton    84
# Name: vendedor, dtype: int64
