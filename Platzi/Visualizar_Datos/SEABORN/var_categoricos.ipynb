# %% [markdown]
# ## Graficar Variables categóricas en Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# ## Gráfico de Conteo

# %% [markdown]
# * Por ejemplo podemos hacer un conteo de los días, y ver cuantos clientes que realizaron el pago fueron hombres u mujeres
# * Puede ser considerado un gráfico de barras, por agrupamiento (groupb by)

# %%
sns.countplot(data=tips, x="day",hue="sex")
plt.show()

# %% [markdown]
# * Interpretación de Gráficos anteriores, los días jueves los clientes hombres y mujeres suelen pagar con la misma regularidad de manera intermedia.
# * Los viernes la clientela por lo visto es mucho menor.
# * Sin embargo los fines de semana, los hombres son los que suelen pagar más en compareción a las mujeres que mantienen un gasto similar al día Jueves por ejemplo.

# %% [markdown]
# ## Gráfico de Conteo en el Eje Y

# %% [markdown]
# * Este es un simple gráfico invertido en el eje Y mismo

# %%
sns.countplot(data=tips, y="day",hue="sex")
plt.show()

# %% [markdown]
# # Grafico de tipo Strip

# %% [markdown]
# * Así podemos enfrentar una variable categórica con una variable numérica
# * Con este tipo de gráficos podemos analizar la distribución que existe en los días con respecto al total de la cuenta, que sería una variable numérica.

# %%
#Categorizamos por Sexo
plt.figure(figsize=(10,8))
sns.stripplot(data=tips,x="day",y="total_bill",hue="sex",dodge=True)
plt.legend(loc="center",bbox_to_anchor=(1.1,0.5))
plt.show()

# %% [markdown]
# * En los fines de semana existen clientes hombres que tienen una cuenta a pagar más considerable
# * Los días viernes se tiene un comportamiento muy disperso, en especial si hablamos de los hombres
# * Los jueves son días mucho más homogéneos.
# * Las mujeres siguen un comporatmiento similar a los jueves los fines de semana.

# %% [markdown]
# ## Gráfico tipo Swarmplot

# %% [markdown]
# * Se emplea si deseamos tener una mejor representación numérica de nuestros datos, los cuales se agrupan en un determinado tramo

# %%
#Categorizamos por Sexo
plt.figure(figsize=(10,8))
sns.swarmplot(data=tips,x="day",y="total_bill",hue="sex",dodge=True)
plt.legend(loc="center",bbox_to_anchor=(1.1,0.5))
plt.show()

# %% [markdown]
# # Gráfico de Tipo Bigote

# %% [markdown]
# * Muy útil para hacer comparaciones de medianas, observar los percentiles, en este caso a travpes de variables categóricas.
# * Por supuesto también nos sirve para dar un vistazo a la existencia de valores atípicos

# %%
#Categorizamos por Sexo
plt.figure(figsize=(10,8))
sns.boxplot(data=tips,x="day",y="total_bill",hue="sex",dodge=True)
plt.legend(loc="center",bbox_to_anchor=(1.1,0.5))
plt.show()

# %% [markdown]
# # Gráfico de Bigote - Numérico

# %%
#Es preferible usar y en estos casos
sns.boxplot(data=tips,y="total_bill")
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %% [markdown]
# ## Combinaciones de gráficos

# %% [markdown]
# * Siempre pensar en las variables que uno desea enfrentar, por ejemplo día y total de cuenta.

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=tips,x="day",y="total_bill",hue="sex",dodge=True)
sns.swarmplot(data=tips,x="day",y="total_bill",color="0",dodge=True,hue="sex",marker="<")
plt.show()

# %% [markdown]
# ## Gráfico de Violín

# %%
sns.violinplot(data=tips,x="day",y="total_bill",hue="sex",palette="pastel",split="True")
plt.show()

# %% [markdown]
# # Gráfico violin - Numérico

# %%
sns.violinplot(data=tips,y="total_bill")
plt.show()

# %% [markdown]
# # Gráfico Categórico Convencional

# %% [markdown]
# * Es como el gráfico por defecto para diagramar variables categóricas, emplea supuestamente el que mejor se ajuste al caso

# %%
#El gráfico que se adapta es catplot. 
sns.catplot(data=tips, x="day",y="total_bill",hue="sex",dodge=True,col="time",kind="box") #kind/box/swarm
#Recuerda que col sirve para separar gráficos por categoría. 
plt.show()

# %% [markdown]
# * Gráficamos como se comportan los grupos de personas por días.

# %%
sns.catplot(data=tips,x="day",col="time",hue="size",kind="count")
plt.show()
