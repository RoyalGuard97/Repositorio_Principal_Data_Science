# %% [markdown]
# # Manipulación de Excepciones

# %%
#Dividir entre 
numerador = 10
denominador = 0

try:
    resultado = numerador/denominador
    print(resultado)
except:
    ZeroDivisionError, print("No se puede operar")
# Out:
# No se puede operar
