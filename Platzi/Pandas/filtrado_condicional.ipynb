# %% [markdown]
# # Filtrado por Condicion

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("betsellers.csv")

# %%
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# * Bonus: df[df["Author"].isin(["George Orwell"])]

# %%
#Mascara de acuerdo a una condicion
condicion = df["Year"] > 2016

# %%
df[condicion]
# Out:
#                                                   Name  \
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# ..                                                 ...
# 544                                             Wonder
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# ...

# %% [markdown]
# + Con este Símbolo ~Negamos una Condicion o máscara en pandas

# %%
df[~((df["Genre"] == "Fiction") & (df["Year"] > 2016))]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# ..                                                 ...
# 543                                             Wonder
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# * BONUS: Filtrado. Buscar textos que contengan un término

# %%
#Recuerdo a un autor, bueno no pero era algo de Martin, lo puedes encontrar?
condicion = df["Author"].str.contains("Martin") #Si algun texto del dataframe contiene!!

df[condicion]
# Out:
#                                                   Name                 Author  \
# 5        A Dance with Dragons (A Song of Ice and Fire)    George R. R. Martin
# 6    A Game of Thrones / A Clash of Kings / A Storm...    George R. R. Martin
# 40            Brown Bear, Brown Bear, What Do You See?        Bill Martin Jr.
# 41            Brown Bear, Brown Bear, What Do You See?        Bill Martin Jr.
# 118  Game of Thrones Boxed Set: A Game of Thrones/A...     George R.R. Martin
# 119  Game of Thrones Boxed Set: A Game of Thrones/A...     George R.R. Martin
# 120  Game of Thrones Boxed Set: A Game of Thrones/A...     George R.R. Martin
# 486                   The Wonderful Things You Will Be  Emily Winfield Martin
# 487                   The Wonderful Things You Will Be  Emily Winfield Martin
# 488                   The Wonderful Things You Will Be  Emily Winfield Martin
# 489                   The Wonderful Things You Will Be  Emily Winfield Martin
#
# ...
