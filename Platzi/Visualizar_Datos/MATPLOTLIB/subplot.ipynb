# %% [markdown]
# # Subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %% [markdown]
# # Crear varios gráficos

# %%
#Primer gráfico de indice 1 - final
plt.subplot(1,2,1)
plt.plot(x,y)
#Segundo gráfico de indice 2 - final
plt.subplot(1,2,2)
plt.hist(y)
plt.show()

# %% [markdown]
# * Puedes representar mucho más en una sola gráfica

# %%
#Primer gráfico de indice 1 - final
plt.subplot(1,2,1)
plt.plot(x,y,"r--")
plt.plot(y,x,"b:")
#Segundo gráfico de indice 2 - final
plt.subplot(1,2,2)
plt.pie(y)
plt.show()

# %% [markdown]
# * El primer indice del subplot, hace referencia a una fila, el segundo hace referencia a una columna

# %%
#Primer gráfico de indice 1 - final
plt.subplot(2,1,1)
plt.plot(x,y,"r--")
plt.plot(y,x,"b:")
#Segundo gráfico de indice 2 - final
plt.subplot(2,1,2)
plt.pie(y)
plt.show()
